# %%
# # Run it once (in one session)
# !pip install decord
# !pip install einops
# !pip install icecream
# !pip install rarfile
# !pip install unrar

# %%
# Imports
import torch
from torch import nn, einsum
from torch.nn import functional as F
from torch.utils.tensorboard import SummaryWriter
import torchvision as tv
from torch.utils.data import random_split, DataLoader,Dataset
import time
import random
import math
import decord
import numpy as np
import gc
from einops import rearrange, repeat,reduce
from einops.layers.torch import Rearrange
from PIL import Image
from tqdm.notebook import tqdm
from icecream import ic
from torchvision.datasets import DatasetFolder
from torchvision.transforms import transforms
from torch.utils.data import DataLoader, random_split
import os
import rarfile
from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms
from torch.utils.data import DataLoader, random_split
import torch.utils.data as data
from torchvision import transforms
from PIL import Image
import torch.nn as nn
import torch.optim as optim
from tqdm.notebook import tqdm
import shutil

import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import operator

# %%
# set device
frames_per_clip = 8
device ='cuda:0' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda:0'

# %% [markdown]
# # DOWNLOADING DATA FROM SOURCE WEBSITE

# %%
# # once per session/runtime
# !wget http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar

# %% [markdown]
# # DATA DIRECTORY SETTINGS

# %%
# # once per session/runtime

# rar_path = './hmdb51_org.rar'  
# extract_path = './dataset' 

# with rarfile.RarFile(rar_path, 'r') as rar:
#     rar.extractall(extract_path)

# %%
# # once per session/runtime

# direcs = os.listdir(extract_path)

# for i in direcs:
#   with rarfile.RarFile(f"dataset/{i}", 'r') as rar:
#     rar.extractall(f"data/{i.split('.')[0]}")

# %%
# once per session/runtime

# %%
# once per session/runtime

# Define the path to the dataset

# %%
class Frame:
    def __init__(self, id, frame, value):
        self.id = id
        self.frame = frame
        self.value = value

    def __lt__(self, other):
        if self.id == other.id:
            return self.id < other.id
        return self.id < other.id

    def __gt__(self, other):
        return other.__lt__(self)

    def __eq__(self, other):
        return self.id == other.id and self.id == other.id

    def __ne__(self, other):
        return not self.__eq__(other)

# %% [markdown]
# # DATA LOADING

# %%
# Dataset Class
class HMDB51Dataset(data.Dataset):
    def __init__(self, dataset_dir, frames_per_clip):
        super().__init__()
        self.dataset_dir = dataset_dir
        self.frames_per_clip = frames_per_clip
        self.video_list = []
        self.labels = []

        # Get the list of video directories
        video_dirs = sorted(os.listdir(dataset_dir))
        
        for label, video_dir in enumerate(video_dirs):
            video_files = os.listdir(os.path.join(dataset_dir, video_dir))
            self.video_list.extend([os.path.join(video_dir, video_file) for video_file in video_files])
            self.labels.extend([label] * len(video_files))
        #print(self.labels)
        self.transform = transforms.Compose([
            transforms.Resize((256, 256)),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])

    def __len__(self):
        return len(self.video_list)

    def __getitem__(self, idx):
        video_path = os.path.join(self.dataset_dir, self.video_list[idx])
        cap = cv2.VideoCapture(str(video_path))


        curr_frame = None
        prev_frame = None

        frame_diffs = []
        frames = []
        ret, frame = cap.read()
        i = 1

        while(ret):
            luv = cv2.cvtColor(frame, cv2.COLOR_BGR2LUV)
            curr_frame = luv
            if curr_frame is not None and prev_frame is not None:
                #logic here
                diff = cv2.absdiff(curr_frame, prev_frame)
                count = np.sum(diff)
                frame_diffs.append(count)
                frame = Frame(i, frame, count)
                frames.append(frame)
            prev_frame = curr_frame
            i = i + 1
            ret, frame = cap.read()
        """
            cv2.imshow('frame',luv)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        """
        cap.release()
        # vid = decord.VideoReader(video_path, ctx=decord.cpu(0))
        # nframes = len(vid)

        # # If the number of frames in the video is less than frames_per_clip, repeat the frames
        # if nframes <= self.frames_per_clip:
        #     frame_idxs = torch.arange(0, self.frames_per_clip) % nframes
        # # Else, sample uniformly separated frames
        # else:
        #     frame_idxs = torch.linspace(0, nframes - 1, self.frames_per_clip).long()

        # frames = []
        # for frame_idx in frame_idxs:
        #     frame_idx = frame_idx.item()  # Convert to scalar value
        #     frame = Image.fromarray(vid[frame_idx].asnumpy())
        #     frame = self.transform(frame)
        #     frames.append(frame)
        frames.sort(key=operator.attrgetter("value"), reverse=True)
        keyframes = []
        for keyframe in frames[:frames_per_clip]:
            frame = Image.fromarray(keyframe.frame)
            frame = self.transform(frame)
            keyframes.append(frame)
        
        keyframes = torch.stack(keyframes)

        label = self.labels[idx]
        #print('Frame for key frame',keyframes.shape)
        return keyframes, label

# %%
# Directory of the HMDB51 dataset
dataset_dir = "./data"
# Data loading parameters
batch_size = 8
test_batch_size = 1
num_workers = 0
pin_memory = True

# Instantiate the dataset
hmdb51_dataset = HMDB51Dataset(dataset_dir,frames_per_clip=frames_per_clip)
num_classes = len(set(hmdb51_dataset.labels))

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
# Split the dataset into train, validation, and test sets
train_len = int(0.7 * len(hmdb51_dataset))
test_len = len(hmdb51_dataset) - train_len - (len(hmdb51_dataset) - train_len)//2
train_data, val_data,test_data = torch.utils.data.random_split(hmdb51_dataset, [train_len,test_len, len(hmdb51_dataset) - test_len - train_len])

# %%
# Dataloaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory,drop_last=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, num_workers=num_workers, pin_memory=pin_memory,drop_last=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=test_batch_size, num_workers=num_workers, pin_memory=pin_memory,drop_last=True)

# %%
# Instantiate and create train-val-test split
# train_val_data = HMDB51Dataset(dataset_dir, frames_per_clip=frames_per_clip)
# train_len = int(0.7 * len(hmdb51_dataset))
# test_len = len(hmdb51_dataset) - train_len - (len(hmdb51_dataset) - train_len)//2
# train_val_split = [train_len,test_len, len(hmdb51_dataset) - test_len - train_len]
# train_data, val_data,test_data = random_split(train_val_data, train_val_split)
# test_data = HMDB51Dataset(dataset_dir, frames_per_clip=frames_per_clip)

# Print the number of samples in each split
print(f"Train samples: {len(train_data)}")
print(f"Validation samples: {len(val_data)}")
print(f"Test samples: {len(test_data)}")
# Out:
# Train samples: 4736
# Validation samples: 1015
# Test samples: 1015

# %% [markdown]
# # DEFINING MODEL

# %%
class MLP(nn.Module):
    """
    Builds a simple feed forward network
    Args:
    - dim: (int) - inner dimension of embeddings
    - inner_dim: (int) - dimension of transformer head
    - n_class: (int) - number of output classes
    - encoder: the DinoVisionTransformer encoder
    """
    def __init__(self, dim, inner_dim, n_class, encoder):
        super().__init__()
        self.encoder = encoder
        self.mlp = nn.Sequential(
            nn.Flatten(),
            nn.Linear(dim*frames_per_clip, n_class)
        )

    def forward(self, x,concat=False):
        B, T, C, H, W = x.shape
        x = x.reshape(B*T, C, H, W)
        output = self.encoder(x)
        if concat:
            output = output.reshape(B, T, -1)
            avg = output.mean(dim=1)  # Average pooling over time
        else:
            avg = output.reshape(B, T, -1)
            #print(avg.shape)
        return self.mlp(avg)

# %%
# Instantiate the model
dinov2_vits14 = torch.hub.load('facebookresearch/dinov2', 'dinov2_vits14')
dinov2_vits14.to(device)
for param in dinov2_vits14.parameters():
    param.requires_grad = False
for i in range(12):
    #dinov2_vits14.blocks[i].add_module('ln',nn.LayerNorm(384))
    dinov2_vits14.blocks[i].add_module('fc1',nn.Linear(384, 384, bias=True))
    dinov2_vits14.blocks[i].add_module('conv',nn.Conv3d(384, 384, kernel_size=(5, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), groups=384))
    dinov2_vits14.blocks[i].add_module('fc2',nn.Linear(384, 384, bias=True))
model = MLP(384, 512, 51, dinov2_vits14)
model.to(device)
# Out:
# Using cache found in /home/z3qian/.cache/torch/hub/facebookresearch_dinov2_main
# MLP(
#   (encoder): DinoVisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 384, kernel_size=(14, 14), stride=(14, 14))
#       (norm): Identity()
#     )
#     (blocks): ModuleList(
#       (0-11): 12 x NestedTensorBlock(
#         (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (attn): MemEffAttention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): LayerScale()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): LayerScale()
#         (drop_path2): Identity()
#         (fc1): Linear(in_features=384, out_features=384, bias=True)
#         (conv): Conv3d(384, 384, kernel_size=(5, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), groups=384)
#         (fc2): Linear(in_features=384, out_features=384, bias=True)
#       )
#     )
#     (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#     (head): Identity()
#   )
#   (mlp): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=3072, out_features=51, bias=True)
#   )
# )

# %% [markdown]
# ## SPECIFYING HYPER-PARAMETERS

# %%
# Define the loss function and optimizer
lr=0.01
epochs = 6
loss_criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr=lr,momentum=0.9,weight_decay=0.01)

# %% [markdown]
# # MODEL TRAINING & EVALUATION

# %%
# Training loop
val_best = 0
for epoch in range(1, epochs + 1):
    model.train()
    total_epoch_loss = 0
    for batch_id, (video_data, labels) in tqdm(enumerate(train_loader)):
        video_data, labels = video_data.to(device), labels.to(device)
        optimizer.zero_grad()
        prediction = model(video_data,False)
        loss = loss_criterion(prediction, labels)
        loss.backward()
        optimizer.step()
        total_epoch_loss += loss.item()
        
        corrects = (torch.argmax(prediction,dim=1)==labels).sum()
        bacc = corrects/batch_size
        del video_data
        del labels

        gc.collect()
        print(f"\n[Train Epoch]: {epoch} Train Loss: {loss.item()}, Batch Acc is {bacc.item()}")

        # Add any additional training metrics/logging you need
        
    # Perform validation at the end of each epoch
    model.eval()
    total_loss = 0
    corrects = 0
    with torch.no_grad():
        for batch_id, (video_data, labels) in enumerate(val_loader):
            video_data, labels = video_data.to(device), labels.to(device)
            prediction = model(video_data)
            loss = loss_criterion(prediction, labels)
            total_loss += loss.item()
            corrects += (torch.argmax(prediction, dim=1) == labels).sum()
            del video_data
            del labels

            gc.collect()
    accuracy = corrects / (len(val_loader) * batch_size)
    print(f"\n[Val Epoch]: {epoch} , Accuracy: {accuracy}, Valid Loss: {total_loss / len(val_loader)}")
    if accuracy > val_best:
        torch.save(model,'best_hmdb_model.pth')
        val_best = accuracy
# Out:
# 0it [00:00, ?it/s]
# [Train Epoch]: 1 Train Loss: 4.564845085144043, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 6.5380096435546875, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 8.827596664428711, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 9.606751441955566, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 11.805667877197266, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 16.492475509643555, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 13.930351257324219, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 23.460969924926758, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 28.48788070678711, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 27.620182037353516, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 22.420068740844727, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 21.702550888061523, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 39.090999603271484, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 16.113754272460938, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 36.160430908203125, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 30.684906005859375, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 23.525022506713867, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 57.79583740234375, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 34.34052276611328, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 60.08473205566406, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 30.552833557128906, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 67.01871490478516, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 21.30923080444336, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 27.658531188964844, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 36.12342834472656, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 26.326343536376953, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 37.12413024902344, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 78.16417694091797, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 43.854061126708984, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 44.751129150390625, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 32.88603210449219, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 38.9004020690918, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 67.56544494628906, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 53.84959411621094, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 38.31476593017578, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 27.365196228027344, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 44.02788162231445, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 69.70404052734375, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 43.908809661865234, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 55.83136749267578, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 62.94825744628906, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 40.32289123535156, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 48.46485900878906, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 34.70841598510742, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 31.202266693115234, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 30.37119483947754, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 64.80776977539062, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 66.50391387939453, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 47.19807052612305, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 90.02596282958984, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 56.591041564941406, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 65.36160278320312, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 37.205055236816406, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 33.23750305175781, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 76.99246978759766, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 48.31050109863281, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 36.66676330566406, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 43.80331039428711, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 57.780696868896484, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 43.774539947509766, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 64.65657806396484, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 38.19704818725586, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 51.27719497680664, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 87.55284118652344, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 67.29747772216797, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 58.49225616455078, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 74.04358673095703, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 58.20599365234375, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 32.54640197753906, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 54.978607177734375, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 50.237022399902344, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 49.63172912597656, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 61.553443908691406, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 33.57682418823242, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 46.96406555175781, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 59.45139694213867, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 52.24700164794922, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 49.23149871826172, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 47.25886154174805, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 46.610897064208984, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 55.866458892822266, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 71.43160247802734, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 38.419456481933594, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 32.409828186035156, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 59.60202407836914, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 63.819671630859375, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 44.770320892333984, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 27.279048919677734, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 46.688804626464844, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 56.276451110839844, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 63.73677062988281, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 33.064109802246094, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 28.745849609375, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 54.32732009887695, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 38.94384002685547, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 34.116458892822266, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 42.985923767089844, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 27.92232894897461, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 44.01897430419922, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 107.10912322998047, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 112.0235595703125, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 44.55038070678711, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 42.53023147583008, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 54.634681701660156, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 79.41693878173828, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 66.81575012207031, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 28.874343872070312, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 95.5008544921875, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 26.901033401489258, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 39.601375579833984, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 33.0062255859375, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 31.197406768798828, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 28.13042640686035, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 20.76746368408203, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 115.69534301757812, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 30.104463577270508, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 52.99954605102539, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 74.7601089477539, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 52.14265060424805, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 25.727617263793945, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 45.88597869873047, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 66.08773040771484, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 64.87451171875, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 51.48444366455078, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 36.48343276977539, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 39.30249786376953, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 31.354211807250977, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 42.1573486328125, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 73.3836898803711, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 51.254642486572266, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 65.54771423339844, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 57.206932067871094, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 51.278419494628906, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 88.29356384277344, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 32.01226043701172, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 42.895118713378906, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 67.51878356933594, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 45.52415084838867, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 35.250938415527344, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 30.451505661010742, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 56.90941619873047, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 48.57349395751953, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 64.9953384399414, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 77.3848876953125, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 110.51776885986328, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 21.14472770690918, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 67.09823608398438, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 69.9677963256836, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 32.14311981201172, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 41.058345794677734, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 73.8051986694336, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 36.546749114990234, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 87.27293395996094, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 68.07699584960938, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 19.40694808959961, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 71.70465850830078, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 39.344268798828125, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 48.008541107177734, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 82.59761810302734, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 12.920758247375488, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 33.83488464355469, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 47.86429214477539, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 30.047748565673828, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 25.024145126342773, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 60.00687026977539, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 59.024818420410156, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 17.461261749267578, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 60.327842712402344, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 38.735008239746094, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 59.86567687988281, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 128.8739471435547, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 25.943113327026367, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 89.20238494873047, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 91.98249053955078, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 22.6463680267334, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 75.0582275390625, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 0.00022630623425357044, Batch Acc is 1.0
#
# [Train Epoch]: 1 Train Loss: 98.1987075805664, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 67.99685668945312, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 35.81879425048828, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 32.944332122802734, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 57.685340881347656, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 38.11429214477539, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 74.45893859863281, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 45.69801712036133, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 50.03025817871094, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 37.75303649902344, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 20.164331436157227, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 37.41336441040039, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 33.23963928222656, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 24.369247436523438, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 38.172027587890625, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 44.998416900634766, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 22.884586334228516, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 46.79310607910156, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 44.610755920410156, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 86.53721618652344, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 60.74540710449219, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 44.08911895751953, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 69.11550903320312, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 46.25291442871094, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 85.92855072021484, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 41.37157440185547, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 66.33912658691406, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 34.46668243408203, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 28.558427810668945, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 28.66108512878418, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 52.502586364746094, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 39.37285614013672, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 89.44707489013672, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 86.25099182128906, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 78.06492614746094, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 21.955842971801758, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 7.087094783782959, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 65.88934326171875, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 132.40586853027344, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 9.088231086730957, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 19.31940460205078, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 44.62748718261719, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 42.646236419677734, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 74.98229217529297, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 101.77630615234375, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 45.33861541748047, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 34.503028869628906, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 59.57032012939453, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 5.9317450523376465, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 65.67091369628906, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 80.23806762695312, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 76.4781494140625, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 81.48837280273438, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 54.086692810058594, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 9.647425651550293, Batch Acc is 0.875
#
# [Train Epoch]: 1 Train Loss: 44.95865249633789, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 36.96288299560547, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 69.14456939697266, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 50.45087814331055, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 63.07157516479492, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 27.683137893676758, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 20.99125862121582, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 40.303489685058594, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 38.236419677734375, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 58.19799041748047, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 62.397029876708984, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 57.13395309448242, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 48.074363708496094, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 61.84833526611328, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 102.67437744140625, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 9.977651596069336, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 52.009857177734375, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 58.82243728637695, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 74.00457763671875, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 34.14672088623047, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 69.8843765258789, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 73.13578033447266, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 92.28522491455078, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 70.40560913085938, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 72.66297912597656, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 24.335803985595703, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 81.49429321289062, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 90.60242462158203, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 85.88793182373047, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 52.49303436279297, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 87.23312377929688, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 43.65837097167969, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 45.16593933105469, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 38.2769660949707, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 28.589771270751953, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 34.58466720581055, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 68.30529022216797, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 55.66033172607422, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 47.96589660644531, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 36.49835968017578, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 33.318965911865234, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 94.30119323730469, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 27.230091094970703, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 82.5757064819336, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 37.34288787841797, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 19.38288116455078, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 37.073524475097656, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 30.00138282775879, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 112.0259017944336, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 65.00971984863281, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 68.62970733642578, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 29.914783477783203, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 72.41891479492188, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 42.29005432128906, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 38.00999069213867, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 60.5755615234375, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 54.98606491088867, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 37.86032485961914, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 74.90689086914062, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 61.10405349731445, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 44.991737365722656, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 62.25331497192383, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 82.52579498291016, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 38.81894302368164, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 55.57449722290039, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 62.28535842895508, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 74.41453552246094, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 45.333900451660156, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 33.54697036743164, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 61.72122573852539, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 59.185752868652344, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 122.04421997070312, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 68.57881927490234, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 31.44963836669922, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 8.128759384155273, Batch Acc is 0.875
#
# [Train Epoch]: 1 Train Loss: 72.02485656738281, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 85.1236343383789, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 45.84096908569336, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 8.978047370910645, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 74.44960021972656, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 70.06980895996094, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 13.29904556274414, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 43.92009735107422, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 37.27159118652344, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 50.45199966430664, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 45.47074890136719, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 68.40851593017578, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 113.01021575927734, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 78.18167877197266, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 116.63629150390625, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 34.739601135253906, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 61.07423782348633, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 94.77117919921875, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 43.59537887573242, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 22.114200592041016, Batch Acc is 0.875
#
# [Train Epoch]: 1 Train Loss: 62.92555618286133, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 52.697120666503906, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 89.54512023925781, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 25.056079864501953, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 41.3486442565918, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 55.68681716918945, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 33.150936126708984, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 31.486860275268555, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 105.88090515136719, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 45.72931671142578, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 61.34638977050781, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 16.267383575439453, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 56.7718391418457, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 53.10422897338867, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 97.76521301269531, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 8.232675552368164, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 60.9466438293457, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 52.02228546142578, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 32.011444091796875, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 29.09650993347168, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 29.349939346313477, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 33.12382125854492, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 31.0606746673584, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 50.760231018066406, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 21.89811897277832, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 100.30789184570312, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 52.18508529663086, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 36.18336486816406, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 31.749881744384766, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 19.419971466064453, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 51.49681091308594, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 32.307525634765625, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 55.97010040283203, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 5.404393672943115, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 75.84982299804688, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 51.64768600463867, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 4.962829113006592, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 49.022518157958984, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 56.92449951171875, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 49.86756896972656, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 45.77452850341797, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 55.78941345214844, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 44.559749603271484, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 28.441917419433594, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 73.81525421142578, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 8.078332901000977, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 21.606739044189453, Batch Acc is 0.875
#
# [Train Epoch]: 1 Train Loss: 88.68138122558594, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 45.83306884765625, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 36.246124267578125, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 103.82159423828125, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 32.54099655151367, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 25.346538543701172, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 50.92325210571289, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 17.309268951416016, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 46.95582580566406, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 55.30714797973633, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 29.882186889648438, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 29.233041763305664, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 60.93006896972656, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 35.246307373046875, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 18.041263580322266, Batch Acc is 0.875
#
# [Train Epoch]: 1 Train Loss: 46.37540817260742, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 37.640785217285156, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 20.438720703125, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 33.76886749267578, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 56.455726623535156, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 44.589542388916016, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 104.35150146484375, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 55.37137222290039, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 23.449565887451172, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 67.33271789550781, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 96.40080261230469, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 51.4831657409668, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 51.625343322753906, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 79.10294342041016, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 42.8905143737793, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 80.34684753417969, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 21.744384765625, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 52.56114959716797, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 81.64419555664062, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 61.567832946777344, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 9.784215927124023, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 50.31471252441406, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 53.81319808959961, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 53.765926361083984, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 40.737098693847656, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 84.8888931274414, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 35.040016174316406, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 22.226537704467773, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 101.20198822021484, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 20.88385772705078, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 82.4030532836914, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 68.5357666015625, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 72.80162811279297, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 67.74308776855469, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 28.69906997680664, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 61.590126037597656, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 63.35508728027344, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 40.79979705810547, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 66.22154235839844, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 28.29933738708496, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 74.96701049804688, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 102.96171569824219, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 59.5438346862793, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 42.07074737548828, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 48.2902946472168, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 38.366641998291016, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 80.2699966430664, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 86.55955505371094, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 29.21055030822754, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 24.928760528564453, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 17.398109436035156, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 23.787513732910156, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 66.50773620605469, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 2.42230224609375, Batch Acc is 0.875
#
# [Train Epoch]: 1 Train Loss: 54.83837890625, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 25.01702117919922, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 89.06148529052734, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 99.16156005859375, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 5.413948059082031, Batch Acc is 0.875
#
# [Train Epoch]: 1 Train Loss: 41.76856231689453, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 101.94144439697266, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 41.709922790527344, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 34.2274055480957, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 109.31645965576172, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 92.18324279785156, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 27.718605041503906, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 13.476195335388184, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 100.20033264160156, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 25.69538116455078, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 75.02936553955078, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 66.19369506835938, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 10.570038795471191, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 15.649422645568848, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 60.26814651489258, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 79.9488754272461, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 66.6515121459961, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 36.611724853515625, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 36.54253005981445, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 72.6482162475586, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 33.920440673828125, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 37.71086883544922, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 55.357452392578125, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 86.87223815917969, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 53.30885696411133, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 153.52349853515625, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 46.87852478027344, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 56.26592254638672, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 9.616682052612305, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 18.824871063232422, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 24.913022994995117, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 66.8364028930664, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 118.42127227783203, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 54.948394775390625, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 90.86959075927734, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 22.97467613220215, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 26.422842025756836, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 63.166969299316406, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 39.20035934448242, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 2.875499963760376, Batch Acc is 0.875
#
# [Train Epoch]: 1 Train Loss: 56.53947448730469, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 67.39848327636719, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 125.31059265136719, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 52.344688415527344, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 36.69584655761719, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 74.25093078613281, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 32.01987838745117, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 17.39609146118164, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 66.62416076660156, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 26.052696228027344, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 46.169456481933594, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 17.83458709716797, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 59.90827178955078, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 92.93299865722656, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 49.0860595703125, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 25.60086441040039, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 63.63943862915039, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 40.03495407104492, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 95.8845443725586, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 58.24629211425781, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 83.97135925292969, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 26.048561096191406, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 31.11588478088379, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 54.91028594970703, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 46.979244232177734, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 77.35218048095703, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 92.41151428222656, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 44.00990295410156, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 53.615760803222656, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 31.782777786254883, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 35.93490982055664, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 93.20333862304688, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 18.72434425354004, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 52.850807189941406, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 29.307327270507812, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 38.77864456176758, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 22.6450138092041, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 21.803749084472656, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 33.16886520385742, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 35.32599639892578, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 17.032840728759766, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 45.46841049194336, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 11.976484298706055, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 19.937984466552734, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 63.847389221191406, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 81.30196380615234, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 24.41764259338379, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 78.49458312988281, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 54.02417755126953, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 12.462323188781738, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 25.526039123535156, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 85.45449829101562, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 24.50210952758789, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 51.15009307861328, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 8.076844215393066, Batch Acc is 0.875
#
# [Train Epoch]: 1 Train Loss: 95.68611145019531, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 91.72749328613281, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 95.0676498413086, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 36.81084060668945, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 79.3790512084961, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 21.26212501525879, Batch Acc is 0.875
#
# [Train Epoch]: 1 Train Loss: 68.77078247070312, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 14.663396835327148, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 26.288179397583008, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 60.05160903930664, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 52.782264709472656, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 21.248144149780273, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 45.429874420166016, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 31.733413696289062, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 80.60847473144531, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 119.63091278076172, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 40.503814697265625, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 59.959228515625, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 27.099044799804688, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 3.586231231689453, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 44.465728759765625, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 35.8311767578125, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 35.54106140136719, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 91.40361022949219, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 33.401519775390625, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 115.76606750488281, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 47.396018981933594, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 16.843090057373047, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 31.438085556030273, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 54.75306701660156, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 35.12983322143555, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 84.05921936035156, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 21.78276252746582, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 55.04600524902344, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 41.76020812988281, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 21.408275604248047, Batch Acc is 0.75
#
# [Train Epoch]: 1 Train Loss: 68.56060028076172, Batch Acc is 0.0
#
# [Train Epoch]: 1 Train Loss: 68.34626770019531, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 52.452152252197266, Batch Acc is 0.625
#
# [Train Epoch]: 1 Train Loss: 54.92779541015625, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 40.141178131103516, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 91.05815124511719, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 46.754600524902344, Batch Acc is 0.125
#
# [Train Epoch]: 1 Train Loss: 52.84734344482422, Batch Acc is 0.5
#
# [Train Epoch]: 1 Train Loss: 46.457427978515625, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 48.77070236206055, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 43.40263366699219, Batch Acc is 0.25
#
# [Train Epoch]: 1 Train Loss: 78.6384506225586, Batch Acc is 0.375
#
# [Train Epoch]: 1 Train Loss: 22.99927520751953, Batch Acc is 0.375
#
# [Val Epoch]: 1 , Accuracy: 0.5138888955116272, Valid Loss: 42.970606847311416
# 0it [00:00, ?it/s]
# [Train Epoch]: 2 Train Loss: 28.75194549560547, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 42.20418930053711, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 10.578426361083984, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 23.03986930847168, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 18.07230567932129, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 84.58663940429688, Batch Acc is 0.375
#
# [Train Epoch]: 2 Train Loss: 17.772993087768555, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 49.50651550292969, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 31.02402687072754, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 32.973167419433594, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 49.025638580322266, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 66.81035614013672, Batch Acc is 0.375
#
# [Train Epoch]: 2 Train Loss: 48.68173599243164, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 33.59652328491211, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 12.180425643920898, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 14.565000534057617, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 28.082149505615234, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 10.212411880493164, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 2.327885866165161, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 54.81298065185547, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 17.157779693603516, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 35.03733444213867, Batch Acc is 0.375
#
# [Train Epoch]: 2 Train Loss: 44.18760299682617, Batch Acc is 0.25
#
# [Train Epoch]: 2 Train Loss: 26.748764038085938, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 26.4451961517334, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 46.832977294921875, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 30.517698287963867, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 47.448909759521484, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 44.44775390625, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 26.78293800354004, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 20.595191955566406, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 13.710318565368652, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 17.778669357299805, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 16.026630401611328, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 27.471628189086914, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 15.089197158813477, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 4.814287185668945, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 2.7561206817626953, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 24.76978302001953, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 18.67647933959961, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 21.299381256103516, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 70.015625, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 17.60223960876465, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 51.39411544799805, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 42.87646484375, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 30.184581756591797, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 42.53404998779297, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 24.12286376953125, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 50.057472229003906, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 11.281492233276367, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 27.222930908203125, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 29.548908233642578, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 8.65187931060791, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 52.392730712890625, Batch Acc is 0.375
#
# [Train Epoch]: 2 Train Loss: 57.63743209838867, Batch Acc is 0.375
#
# [Train Epoch]: 2 Train Loss: 59.755218505859375, Batch Acc is 0.375
#
# [Train Epoch]: 2 Train Loss: 31.094810485839844, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 30.31511878967285, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 31.249855041503906, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 6.890398025512695, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 33.589515686035156, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 43.202327728271484, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 41.28703308105469, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 1.8216350078582764, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 33.508750915527344, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 63.046485900878906, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 31.885421752929688, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 1.713927984237671, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 15.471186637878418, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 20.16560935974121, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 25.33394432067871, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 23.0638427734375, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 50.673248291015625, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 32.32735824584961, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 61.35997009277344, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 35.56242370605469, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 58.80597686767578, Batch Acc is 0.25
#
# [Train Epoch]: 2 Train Loss: 29.578092575073242, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 24.419532775878906, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 19.515979766845703, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 37.7738037109375, Batch Acc is 0.375
#
# [Train Epoch]: 2 Train Loss: 48.866058349609375, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 3.2218737602233887, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 12.70511245727539, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 20.710119247436523, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 15.710826873779297, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 1.4496991634368896, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 52.41675567626953, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 12.55419921875, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 26.99150276184082, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 41.90163040161133, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 16.995512008666992, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 20.440031051635742, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 16.409400939941406, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 15.24593734741211, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 59.26793670654297, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 29.457611083984375, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 6.207900524139404, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 14.297475814819336, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 25.735755920410156, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 81.87200927734375, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 50.827537536621094, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 47.10686111450195, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 37.937992095947266, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 22.386035919189453, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 17.315431594848633, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 9.270634651184082, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 34.766693115234375, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 34.22017288208008, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 27.396320343017578, Batch Acc is 0.75
#
# [Train Epoch]: 2 Train Loss: 0.00013652436609845608, Batch Acc is 1.0
#
# [Train Epoch]: 2 Train Loss: 64.1510238647461, Batch Acc is 0.375
#
# [Train Epoch]: 2 Train Loss: 25.80218505859375, Batch Acc is 0.625
#
# [Train Epoch]: 2 Train Loss: 5.078980445861816, Batch Acc is 0.875
#
# [Train Epoch]: 2 Train Loss: 33.11168670654297, Batch Acc is 0.375
#
# [Train Epoch]: 2 Train Loss: 74.53459167480469, Batch Acc is 0.5
#
# [Train Epoch]: 2 Train Loss: 44.924320220947266, Batch Acc is 0.375
#
# ...
#
# [Train Epoch]: 6 Train Loss: 14.859712600708008, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 22.345977783203125, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 19.02339744567871, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 4.388219356536865, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 17.865568161010742, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 42.70549774169922, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 10.590007781982422, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 25.015365600585938, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 0.0, Batch Acc is 1.0
#
# [Train Epoch]: 6 Train Loss: 9.31153392791748, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 28.039398193359375, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 53.081764221191406, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 7.24755859375, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 55.821922302246094, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 20.283214569091797, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 60.39299392700195, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 33.13040542602539, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 13.009259223937988, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 30.489778518676758, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 10.084589004516602, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 48.430824279785156, Batch Acc is 0.25
#
# [Train Epoch]: 6 Train Loss: 29.190401077270508, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 3.7574219703674316, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 19.91086769104004, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 19.65758514404297, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 25.50496482849121, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 61.96167755126953, Batch Acc is 0.25
#
# [Train Epoch]: 6 Train Loss: 25.011892318725586, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 64.00174713134766, Batch Acc is 0.125
#
# [Train Epoch]: 6 Train Loss: 8.931129455566406, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 21.509126663208008, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 32.47065734863281, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 15.5465087890625, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 25.264453887939453, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 38.34120178222656, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 16.090974807739258, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 13.457611083984375, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 77.01982116699219, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 56.513328552246094, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 28.574432373046875, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 57.731510162353516, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 37.63602066040039, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 9.244234085083008, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 30.591339111328125, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 15.822698593139648, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 25.768001556396484, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 4.359248161315918, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 46.35820007324219, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 31.348316192626953, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 19.263566970825195, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 26.972322463989258, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 52.29731750488281, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 37.46426010131836, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 64.42356872558594, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 29.431625366210938, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 36.81395721435547, Batch Acc is 0.25
#
# [Train Epoch]: 6 Train Loss: 12.933792114257812, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 54.023597717285156, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 8.974455833435059, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 4.84431266784668, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 25.17709732055664, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 6.637735366821289, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 29.946575164794922, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 15.433988571166992, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 64.51399230957031, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 19.92269515991211, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 10.294593811035156, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 24.093156814575195, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 1.279439091682434, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 55.86680221557617, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 11.404876708984375, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 22.373056411743164, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 25.252159118652344, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 66.21600341796875, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 39.52863311767578, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 21.928871154785156, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 61.41367721557617, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 2.91090989112854, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 53.151573181152344, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 25.721908569335938, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 5.285446643829346, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 30.392061233520508, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 28.29883575439453, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 19.470428466796875, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 9.344512939453125, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 27.968704223632812, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 0.8718355894088745, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 36.48256301879883, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 21.500364303588867, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 22.534282684326172, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 16.930770874023438, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 38.70167922973633, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 45.52488327026367, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 26.032085418701172, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 24.865211486816406, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 18.54926300048828, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 12.1439847946167, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 50.04228210449219, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 35.07633590698242, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 1.026010513305664, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 26.07341766357422, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 39.83121109008789, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 16.9437313079834, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 23.043895721435547, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 16.799427032470703, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 35.63203430175781, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 39.199256896972656, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 24.826419830322266, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 28.58936309814453, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 11.490386962890625, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 0.7989957928657532, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 6.105223655700684, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 36.33589172363281, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 8.251922607421875, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 25.582151412963867, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 43.031978607177734, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 5.977326393127441, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 53.73707580566406, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 30.33565902709961, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 22.05734634399414, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 44.10469436645508, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 16.049617767333984, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 27.691619873046875, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 47.96868133544922, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 4.363556385040283, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 28.794179916381836, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 5.646790504455566, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 28.80328941345215, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 35.82787322998047, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 34.69390106201172, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 36.55445098876953, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 30.939973831176758, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 36.134944915771484, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 38.586090087890625, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 36.534481048583984, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 52.027061462402344, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 14.89719295501709, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 21.3852481842041, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 71.12239074707031, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 41.961605072021484, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 73.01504516601562, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 12.644843101501465, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 19.442909240722656, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 7.974955081939697, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 38.65353012084961, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 7.372686386108398, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 17.576290130615234, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 17.047653198242188, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 27.150297164916992, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 32.79068374633789, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 41.286930084228516, Batch Acc is 0.25
#
# [Train Epoch]: 6 Train Loss: 2.8994667530059814, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 12.576748847961426, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 19.214599609375, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 53.34259796142578, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 38.158470153808594, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 52.24531555175781, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 68.86725616455078, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 34.74022674560547, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 97.07316589355469, Batch Acc is 0.25
#
# [Train Epoch]: 6 Train Loss: 12.626102447509766, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 11.966558456420898, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 17.50783920288086, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 12.43157958984375, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 64.03323364257812, Batch Acc is 0.25
#
# [Train Epoch]: 6 Train Loss: 19.4027042388916, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 31.088611602783203, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 43.37587356567383, Batch Acc is 0.25
#
# [Train Epoch]: 6 Train Loss: 49.23932647705078, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 25.799198150634766, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 44.84434127807617, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 24.120994567871094, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 12.781508445739746, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 10.201983451843262, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 32.159847259521484, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 22.79509925842285, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 0.9930024147033691, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 12.573821067810059, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 49.80548858642578, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 24.056591033935547, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 12.299918174743652, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 66.75118255615234, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 12.48989486694336, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 13.419343948364258, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 21.925994873046875, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 22.72564697265625, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 32.670841217041016, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 10.691877365112305, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 9.754157066345215, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 34.641231536865234, Batch Acc is 0.125
#
# [Train Epoch]: 6 Train Loss: 32.92498016357422, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 35.69063949584961, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 28.204769134521484, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 22.06776237487793, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 69.33377075195312, Batch Acc is 0.25
#
# [Train Epoch]: 6 Train Loss: 27.78716468811035, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 23.821144104003906, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 6.904562950134277, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 30.049890518188477, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 57.2032356262207, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 34.43528747558594, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 54.663917541503906, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 40.49581527709961, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 21.991960525512695, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 35.731285095214844, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 78.2379379272461, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 19.535259246826172, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 18.455080032348633, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 25.65384864807129, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 43.451236724853516, Batch Acc is 0.125
#
# [Train Epoch]: 6 Train Loss: 23.539011001586914, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 48.321815490722656, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 52.59733581542969, Batch Acc is 0.25
#
# [Train Epoch]: 6 Train Loss: 35.557125091552734, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 25.15920639038086, Batch Acc is 0.375
#
# [Train Epoch]: 6 Train Loss: 32.023887634277344, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 1.0430808572436945e-07, Batch Acc is 1.0
#
# [Train Epoch]: 6 Train Loss: 27.60548973083496, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 14.779548645019531, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 14.207444190979004, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 28.643455505371094, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 16.216445922851562, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 17.556602478027344, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 46.38602828979492, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 21.606884002685547, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 40.81817626953125, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 12.347980499267578, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 13.218491554260254, Batch Acc is 0.5
#
# [Train Epoch]: 6 Train Loss: 12.499846458435059, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 28.073871612548828, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 25.66019058227539, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 14.953784942626953, Batch Acc is 0.75
#
# [Train Epoch]: 6 Train Loss: 11.44826889038086, Batch Acc is 0.875
#
# [Train Epoch]: 6 Train Loss: 71.997314453125, Batch Acc is 0.625
#
# [Train Epoch]: 6 Train Loss: 29.90528106689453, Batch Acc is 0.5
#
# [Val Epoch]: 6 , Accuracy: 0.5089285969734192, Valid Loss: 48.458856523983066

# %%
# Save the trained model
#torch.save(model, "hmdb_st_model.pth")
model = torch.load('best_hmdb_model.pth')
model.to(device)
# Out:
# MLP(
#   (encoder): DinoVisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 384, kernel_size=(14, 14), stride=(14, 14))
#       (norm): Identity()
#     )
#     (blocks): ModuleList(
#       (0-11): 12 x NestedTensorBlock(
#         (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (attn): MemEffAttention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): LayerScale()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): LayerScale()
#         (drop_path2): Identity()
#         (fc1): Linear(in_features=384, out_features=384, bias=True)
#         (conv): Conv3d(384, 384, kernel_size=(5, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), groups=384)
#         (fc2): Linear(in_features=384, out_features=384, bias=True)
#       )
#     )
#     (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#     (head): Identity()
#   )
#   (mlp): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=3072, out_features=51, bias=True)
#   )
# )

# %%
def test_model(loader):

    model.eval()
    corrects=0
    total_loss = 0
    with torch.no_grad():
        for batch_id, (input_data,labels) in enumerate(loader):
            
            input_data = input_data.to(device)
            
            labels = labels.to(device)
            prediction = model(input_data)
            loss = loss_criterion(prediction,labels)
            total_loss += loss.item()
            corrects+= (torch.argmax(prediction,dim=1)==labels).sum()
    
    accuracy = corrects/(len(loader)*test_batch_size)
    print(f"Test Accuracy: {accuracy}, Test Loss: {total_loss}")

    return accuracy

# %%
test_model(test_loader)
# Out:
# Test Accuracy: 0.5536946058273315, Test Loss: 41916.75852078217
# tensor(0.5537, device='cuda:0')
